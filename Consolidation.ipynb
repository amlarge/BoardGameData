# %%
import pandas as pd
import fuzzy_pandas as fpd
import re
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df1=pd.read_csv("/dbfs/mnt/sapbio-client-001sap/001SAP21P004-ME/00-ProjectData/original/main/MESA1.description.csv")
df2=pd.read_csv("/dbfs/mnt/sapbio-client-001sap/001SAP21P004-ME/00-ProjectData/original/main/MESA2.description.csv")
df3=pd.read_csv("/dbfs/mnt/sapbio-client-001sap/001SAP21P004-ME/00-ProjectData/original/main/MESA3.description.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df1=pd.read_csv("/dbfs/mnt/sapbio-client-001sap/001SAP21P004-ME/00-ProjectData/original/main/MESA1.description.csv")
df2=pd.read_csv("/dbfs/mnt/sapbio-client-001sap/001SAP21P004-ME/00-ProjectData/original/main/MESA2.description.csv")
df3=pd.read_csv("/dbfs/mnt/sapbio-client-001sap/001SAP21P004-ME/00-ProjectData/original/main/MESA3.description.csv")
dlist=[df2,df3]
for D in dlist:
  for idx,row in D.iterrows():
    if re.search('[a-zA-z]*2([c,t])?$',row['variable']):
      string=re.search('[a-zA-z]*2([c,t])?$',row['variable']).group(0)
      test=re.search('[a-zA-z]*',row['variable']).group(0)

      t=df1.loc[df1['variable'].str.contains(test, case=False),'variable'].to_string(index=False)
      print(t)
      print(string)
      df1.loc[df1['variable'].str.contains(test, case=False),'variable']=str(t)+', '+string
    else:
      df1.append(row)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"> site1c
# site2c
#     age1c
#  agecat1c
#  bphxage1
#  bpmageu1
#  cholage1
#  chlageu1
#    dbage1
#   dbageu1
#  agebrth1
#  hystage1
#   ovaage1
#  menoage1
#  hrmrage1
#  hrmsage1
#  hrmage1c
#  hrmqage1
#  aspsage1
#  aspeage1
#   agesmk1
#  agequit1
#   cgrage1
#  cgrageq1
#   pipage1
#  pipageq1
#   chwage1
#  chwageq1
#   snfage1
#  snfageq1
#   alcage1
# age2c
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
#      age1c\n agecat1c\n bphxage1\n bpmageu1\n c...
# agecat2c
#  agatum1c
# agatum2c
#  volum1c
# volum2c
#  volsum1c
# volsum2c
#  agatpm1c
# agatpm2c
#  volpm1c
# volpm2c
# Series([], )
# vospm2c
#  htcm1
# htcm2
#  wtlb1
# wtlb2
#  hipcm1
# hipcm2
#  waistcm1
# waistcm2
#     bmi1c
#  bmicat1c
#  chbmig1c
# bmi2c
#      bmi1c\n bmicat1c\n chbmig1c, bmi2c
#      bmi1c\n bmicat1c\n chbmig1c, bmi2c
#      bmi1c\n bmicat1c\n chbmig1c, bmi2c
# bmicat2c
#  bsa1c
# bsa2c
#  trig1
# trig2
#      ldl1
#  ldlcat1c
#  vldlp31c
#   ldlp31c
#    oxldl1
# ldl2
#      hdl1
#  hdlcat1c
#   hdlp31c
#  nhdlc31c
#     hdl11
#     hdl21
#     hdl31
#     hdl41
#     hdl51
#     hdl61
#     hdl71
#     hdl81
#   hdl1md1
#   hdl2md1
#   hdl3md1
#   hdl4md1
#   hdl5md1
#   hdl6md1
#   hdl7md1
#   hdl8md1
# hdl2
#  glucos1c
#  glucos1u
# glucos2c
#      chol1
#   cholmed1
#   hghchol1
#  chcholg1c
# chol2
# Series([], )
# c2
#  chlcat1c
# chlcat2c
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
#       hdl1\n hdlcat1c\n  hdlp31c\n nhdlc31c\n  ...
# hdlcat2c
#       ldl1\n ldlcat1c\n vldlp31c\n  ldlp31c\n  ...
#       ldl1\n ldlcat1c\n vldlp31c\n  ldlp31c\n  ...
#       ldl1\n ldlcat1c\n vldlp31c\n  ldlp31c\n  ...
#       ldl1\n ldlcat1c\n vldlp31c\n  ldlp31c\n  ...
#       ldl1\n ldlcat1c\n vldlp31c\n  ldlp31c\n  ...
# ldlcat2c
# Series([], )
# trigcat2c
#  diabins1
# diabins2
#  lastdrk1
# lastdrk2
#    dm031c
#  dmtype1c
#   olvedm1
#   mhxadm1
#   phxadm1
#   hlfadm1
#   nhdadm1
#    nhdmo1
#  dmapnum1
#  olvedm1t
#  pactadm1
#   yrdmn1c
#   yrdmt1c
#  condmn1c
#  condmt1c
# 2c
#  ualbumn1
# ualbumn2
#  ualbcre1
# ualbcre2
#  ucreat1
# ucreat2
#  uabcat1c
# uabcat2c
# Series([], )
# hlthage2
#  emphys1
# emphys2
#  asthma1
# asthma2
#  arthrit1
# arthrit2
#  rheuhv1
# rheuhv2
#  liverd1
# liverd2
#  cirrh1
# cirrh2
#  hepat1
# hepat2
#  kdnydis1
# kdnydis2
# Series([], )
# levwalk2
# Series([], )
# hilwalk2
# Series([], )
# stpwalk2
#  fever1
# fever2
#  coldflu1
# coldflu2
#  urininf1
# urininf2
#  bronch1
# bronch2
#  sinuinf1
# sinuinf2
#  pneumo1
# pneumo2
#   arthrit1, arthrit2
#             arth2wk1
# wk2
#                abi1c
#              diabhx1
#              diabet1
#               abnum1
#                noab1
#             ab5ynum1
#              noab5y1
#             aabpcmp1
#             aabptid1
#             aabprid1
#             aabpdid1
#   diabins1, diabins2
#   uabcat1c, uabcat2c
#               havab1
#              havab1c
#              abcact1
#              abcaga1
# ynum2
#                 abi1c\n             diabhx1\n  ...
#                 abi1c\n             diabhx1\n  ...
#                 abi1c\n             diabhx1\n  ...
#                 abi1c\n             diabhx1\n  ...
#                 abi1c\n             diabhx1\n  ...
#                 abi1c\n             diabhx1\n  ...
#                 abi1c\n             diabhx1\n  ...
#                 abi1c\n             diabhx1\n  ...
#                 abi1c\n             diabhx1\n  ...
#                 abi1c\n             diabhx1\n  ...
#                 abi1c\n             diabhx1\n  ...
#                 abi1c\n             diabhx1\n  ...
#                 abi1c\n             diabhx1\n  ...
#                 abi1c\n             diabhx1\n  ...
#                 abi1c\n             diabhx1\n  ...
#                 abi1c\n             diabhx1\n  ...
#                 abi1c\n             diabhx1\n  ...
# noab2
#  aspirin1
# aspirin2
#  aspdays1
# aspdays2
# Series([], )
# hystchk2
#  hystrct1
# hystrct2
# Series([], )
# hystage2
# Series([], )
# ovarchk2
#  ovaremn1
# ovaremn2
#              ovarem1
#   ovaremn1, ovaremn2
# ovarem2
# Series([], )
# ovaage2
# Series([], )
# menochk2
# Series([], )
# menper2
#  prdsnum1
# prdsnum2
#   hrmrep1
#  hrmrepc1
# hrmrep2
#    hrmrep1\n hrmrepc1, hrmrep2
#    hrmrep1\n hrmrepc1, hrmrep2
# hrmrepc2
# Series([], )
# hrmrage2
# Series([], )
# hrmsage2
# Series([], )
# hrmqage2
#  hrmtyp1
# hrmtyp2
#  asacat1c
# asacat2c
#  sbp1c
# sbp2c
#    dbp1c
#  dbpreg1
# dbp2c
#  spp1c
# spp2c
# Series([], )
# hrdina2c
#  htnmed1c
#     htn1c
#  htnstg1c
# htn2c
# Series([], )
# empstat2
#  curjob1
# curjob2
#  homemkr1
# homemkr2
#  income1
# income2
#  numhhld1
# numhhld2
#  hometyp1
# hometyp2
#  hiprv1
# hiprv2
#  himdcr1
# himdcr2
#  himdcd1
# himdcd2
#  himil1
# himil2
#  hinone1
# hinone2
#  hioth1
# hioth2
#  chsmkstat1c
# smkstat2
#  cursmk1
# cursmk2
#  cigsday1
# cigsday2
#  othtob1
# othtob2
#  shndsmk1
# shndsmk2
#  curalc1
# curalc2
#                cig1c
#   cigsday1, cigsday2
#               cigar1
# cig2c
#  pkyrs1c
# pkyrs2c
#  nhhldc1
# nhhldc2
#  nhhlde1
# nhhlde2
# Series([], )
# invest2
# Series([], )
# ownland2
# Series([], )
# owncar2
# Series([], )
# dadschl2
# Series([], )
# momschl2
#  medcare1
# medcare2
#  medctxt1
# medctxt2
#  hinstxt1
# hinstxt2
#  cgrcur1
# cgrcur2
#  cgrday1
# cgrday2
#  pipcur1
# pipcur2
#  pipday1
# pipday2
#   chew1
#  chew1c
# chew2
#  chwday1
# chwday2
#  snuff1
# snuff2
#  snfday1
# snfday2
# Series([], )
# rwinewk2
# Series([], )
# wwinewk2
# Series([], )
# beerwk2
# Series([], )
# liqwk2
#  highalc1
# highalc2
#  totmed1c
# totmed2
#       age1c\n agecat1c\n bphxage1\n bpmageu1\n ...
#       age1c\n agecat1c\n bphxage1\n bpmageu1\n ...
#                                             race1c
#                                           mexican1
#                                             cuban1
#                                              lang1
#       bmi1c\n bmicat1c\n chbmig1c, bmi2c\n     ...
#       bmi1c\n bmicat1c\n chbmig1c, bmi2c\n     ...
#                 cig1c\n  cigsday1, cigsday2\n  ...

# %%
df1=pd.read_csv("/dbfs/mnt/sapbio-client-001sap/001SAP21P004-ME/00-ProjectData/original/main/MESA1.description.csv")
df2=pd.read_csv("/dbfs/mnt/sapbio-client-001sap/001SAP21P004-ME/00-ProjectData/original/main/MESA2.description.csv")
df3=pd.read_csv("/dbfs/mnt/sapbio-client-001sap/001SAP21P004-ME/00-ProjectData/original/main/MESA3.description.csv")
df4=pd.read_csv("/dbfs/mnt/sapbio-client-001sap/001SAP21P004-ME/00-ProjectData/original/main/MESA4.description.csv")
df5=pd.read_csv("/dbfs/mnt/sapbio-client-001sap/001SAP21P004-ME/00-ProjectData/original/main/MESA5.description.csv")
df6=pd.read_csv("/dbfs/mnt/sapbio-client-001sap/001SAP21P004-ME/00-ProjectData/original/main/MESA6.description.csv")

Dlist=[df2,df3,df4,df5,df6]
fulldata=df1[['variable','description']]
for D in Dlist:
  fulldata=fulldata.merge(D[['variable','description']],how='outer',on='description')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
F=fulldata.set_index('description').stack().reset_index().drop('level_1', axis=1, inplace=False).drop_duplicates()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
F.to_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P004-ME/00-ProjectData/original/main/MESA6_concat.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
FH=pd.read_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P003-FH/04-DataAnalysis/pheno/FH_exam8_plasma_phenotype.description.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df5[df5['description'].str.contains("FAMILY")]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[132]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>description</th>
#       <th>note</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>223</th>
#       <td>income5</td>
#       <td>TOTAL GROSS FAMILY INCOME</td>
#       <td>1: 1: &lt; $5000; 2: 2: $5000 - $7999; 3: 3: $800...</td>
#     </tr>
#     <tr>
#       <th>224</th>
#       <td>numhhld5</td>
#       <td># PEOPLE SUPPORTED BY FAMILY INCOME</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>225</th>
#       <td>nhhldc5</td>
#       <td># CHILDREN SUPPORTED BY FAMILY INCOME</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>226</th>
#       <td>nhhlde5</td>
#       <td># ADULTS &gt; 65 SUPPORTED BY FAMILY INCOME</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
t=df1.loc[df1['variable'].str.contains("site", case=False),'variable'].to_string(index=False)

df1.loc[df1['variable'].str.contains("site", case=False),'variable']=str(t)+', '+'site2c'
df1.loc[df1['variable'].str.contains("site", case=False),'variable']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[51]: 11     site1c, site2c
# Name: variable, dtype: object</div>

# %%
t=df1.loc[df1['variable'].str.contains("site", case=False),'variable'].to_string(index=False)

t
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[50]: &#39; site1c&#39;</div>

# %%
F=pd.read_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P004-ME/00-ProjectData/original/main/MESA6_concat.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
G= F.groupby(['description'],as_index=False)['variable'].apply(', '.join).reset_index()
G.description=G.description.str.lower()
G.description=G.description.str.split(" exam [0-9]").str[0]

G
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[121]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>description</th>
#       <th>variable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>region of birth - maternal grandmother</td>
#       <td>mmrgbth1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>region of birth - paternal grandmother</td>
#       <td>pmrgbth1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>where do you go for medical care</td>
#       <td>medcare2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>#  adults age &gt; 65 supported by family income</td>
#       <td>nhhlde1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>#  of times treated w/ antibiotics, past year</td>
#       <td>abnum1, ab1ynum2, ab1ynum3</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1168</th>
#       <td>1168</td>
#       <td>you are called names or insulted</td>
#       <td>insult1</td>
#     </tr>
#     <tr>
#       <th>1169</th>
#       <td>1169</td>
#       <td>you are threatened or harassed</td>
#       <td>threat1</td>
#     </tr>
#     <tr>
#       <th>1170</th>
#       <td>1170</td>
#       <td>youngs modulus (mmhg/mm)</td>
#       <td>youngm1</td>
#     </tr>
#     <tr>
#       <th>1171</th>
#       <td>1171</td>
#       <td>z score maximum imt</td>
#       <td>zmximt1c</td>
#     </tr>
#     <tr>
#       <th>1172</th>
#       <td>1172</td>
#       <td>[ascvd] estimated 10-yr acvd rate (goff et al ...</td>
#       <td>ascvd1c, ascvd2c, ascvd3c, ascvd4c, ascvd5c</td>
#     </tr>
#   </tbody>
# </table>
# <p>1173 rows × 3 columns</p>
# </div>

# %%
H=G.groupby(['description'],as_index=False)['variable'].apply(', '.join).reset_index()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
G[G['description'].str.contains("age")]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[122]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>description</th>
#       <th>variable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>#  adults age &gt; 65 supported by family income</td>
#       <td>nhhlde1</td>
#     </tr>
#     <tr>
#       <th>118</th>
#       <td>118</td>
#       <td>age at</td>
#       <td>age1c</td>
#     </tr>
#     <tr>
#       <th>119</th>
#       <td>119</td>
#       <td>age at</td>
#       <td>age2c</td>
#     </tr>
#     <tr>
#       <th>120</th>
#       <td>120</td>
#       <td>age at</td>
#       <td>age3c</td>
#     </tr>
#     <tr>
#       <th>121</th>
#       <td>121</td>
#       <td>age at</td>
#       <td>age4c</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1109</th>
#       <td>1109</td>
#       <td>unfairly discouraged by a teacher from continu...</td>
#       <td>uf1educ1</td>
#     </tr>
#     <tr>
#       <th>1110</th>
#       <td>1110</td>
#       <td>unfairly discouraged by a teacher, during last...</td>
#       <td>uf3educ1</td>
#     </tr>
#     <tr>
#       <th>1111</th>
#       <td>1111</td>
#       <td>unfairly discouraged by a teacher, reason</td>
#       <td>uf2educ1</td>
#     </tr>
#     <tr>
#       <th>1147</th>
#       <td>1147</td>
#       <td>weight at age 20 (lbs)</td>
#       <td>wt20lb1</td>
#     </tr>
#     <tr>
#       <th>1148</th>
#       <td>1148</td>
#       <td>weight at age 40 (lbs)</td>
#       <td>wt40lb1</td>
#     </tr>
#   </tbody>
# </table>
# <p>80 rows × 3 columns</p>
# </div>

# %%
H[H['description'].str.contains("age")]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[124]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>description</th>
#       <th>variable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>#  adults age &gt; 65 supported by family income</td>
#       <td>nhhlde1</td>
#     </tr>
#     <tr>
#       <th>119</th>
#       <td>119</td>
#       <td>age at</td>
#       <td>age1c, age2c, age3c, age4c, age5c, age6c</td>
#     </tr>
#     <tr>
#       <th>120</th>
#       <td>120</td>
#       <td>age at first live birth</td>
#       <td>agebrth1</td>
#     </tr>
#     <tr>
#       <th>121</th>
#       <td>121</td>
#       <td>age at hysterectomy</td>
#       <td>hystage1, hystage2, hystage3, hystage4</td>
#     </tr>
#     <tr>
#       <th>122</th>
#       <td>122</td>
#       <td>age categories</td>
#       <td>agecat2c, agecat4c, agecat5c, agecat6c</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1060</th>
#       <td>1060</td>
#       <td>unfairly discouraged by a teacher from continu...</td>
#       <td>uf1educ1</td>
#     </tr>
#     <tr>
#       <th>1061</th>
#       <td>1061</td>
#       <td>unfairly discouraged by a teacher, during last...</td>
#       <td>uf3educ1</td>
#     </tr>
#     <tr>
#       <th>1062</th>
#       <td>1062</td>
#       <td>unfairly discouraged by a teacher, reason</td>
#       <td>uf2educ1</td>
#     </tr>
#     <tr>
#       <th>1096</th>
#       <td>1096</td>
#       <td>weight at age 20 (lbs)</td>
#       <td>wt20lb1</td>
#     </tr>
#     <tr>
#       <th>1097</th>
#       <td>1097</td>
#       <td>weight at age 40 (lbs)</td>
#       <td>wt40lb1</td>
#     </tr>
#   </tbody>
# </table>
# <p>71 rows × 3 columns</p>
# </div>

# %%
H.to_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P004-ME/04-DataAnalysis/pheno/ME_fuzzy_description.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import fuzzywuzzy
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

def fuzzy_merge(df_1, df_2, key1, key2, threshold=90, limit=2):
    """
    :param df_1: the left table to join
    :param df_2: the right table to join
    :param key1: key column of the left table
    :param key2: key column of the right table
    :param threshold: how close the matches should be to return a match, based on Levenshtein distance
    :param limit: the amount of matches that will get returned, these are sorted high to low
    :return: dataframe with boths keys and matches
    """
    s = df_2[key2].tolist()
    
    m = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))    
    df_1['matches'] = m
    
    m2 = df_1['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
    df_1['matches'] = m2
    
    return df_1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fuzzy_merge(F, FH, 'description', 'description', threshold=80)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">TypeError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-4464235365954455&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>fuzzy_merge<span class="ansi-blue-fg">(</span>F<span class="ansi-blue-fg">,</span> FH<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#39;description&#39;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#39;description&#39;</span><span class="ansi-blue-fg">,</span> threshold<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">80</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">&lt;command-4464235365954454&gt;</span> in <span class="ansi-cyan-fg">fuzzy_merge</span><span class="ansi-blue-fg">(df_1, df_2, key1, key2, threshold, limit)</span>
# <span class="ansi-green-intense-fg ansi-bold">     18</span>     df_1<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;matches&#39;</span><span class="ansi-blue-fg">]</span> <span class="ansi-blue-fg">=</span> m
# <span class="ansi-green-intense-fg ansi-bold">     19</span>
# <span class="ansi-green-fg">---&gt; 20</span><span class="ansi-red-fg">     </span>m2 <span class="ansi-blue-fg">=</span> df_1<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;matches&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">.</span>apply<span class="ansi-blue-fg">(</span><span class="ansi-green-fg">lambda</span> x<span class="ansi-blue-fg">:</span> <span class="ansi-blue-fg">&#39;, &#39;</span><span class="ansi-blue-fg">.</span>join<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">[</span>i<span class="ansi-blue-fg">[</span><span class="ansi-cyan-fg">0</span><span class="ansi-blue-fg">]</span> <span class="ansi-green-fg">for</span> i <span class="ansi-green-fg">in</span> x <span class="ansi-green-fg">if</span> i<span class="ansi-blue-fg">[</span><span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">]</span> <span class="ansi-blue-fg">&gt;=</span> threshold<span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     21</span>     df_1<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;matches&#39;</span><span class="ansi-blue-fg">]</span> <span class="ansi-blue-fg">=</span> m2
# <span class="ansi-green-intense-fg ansi-bold">     22</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/core/series.py</span> in <span class="ansi-cyan-fg">apply</span><span class="ansi-blue-fg">(self, func, convert_dtype, args, **kwds)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4211</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   4212</span>                 values <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>astype<span class="ansi-blue-fg">(</span>object<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>_values
# <span class="ansi-green-fg">-&gt; 4213</span><span class="ansi-red-fg">                 </span>mapped <span class="ansi-blue-fg">=</span> lib<span class="ansi-blue-fg">.</span>map_infer<span class="ansi-blue-fg">(</span>values<span class="ansi-blue-fg">,</span> f<span class="ansi-blue-fg">,</span> convert<span class="ansi-blue-fg">=</span>convert_dtype<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4214</span>
# <span class="ansi-green-intense-fg ansi-bold">   4215</span>         <span class="ansi-green-fg">if</span> len<span class="ansi-blue-fg">(</span>mapped<span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">and</span> isinstance<span class="ansi-blue-fg">(</span>mapped<span class="ansi-blue-fg">[</span><span class="ansi-cyan-fg">0</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span> Series<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">pandas/_libs/lib.pyx</span> in <span class="ansi-cyan-fg">pandas._libs.lib.map_infer</span><span class="ansi-blue-fg">()</span>
#
# <span class="ansi-green-fg">&lt;command-4464235365954454&gt;</span> in <span class="ansi-cyan-fg">&lt;lambda&gt;</span><span class="ansi-blue-fg">(x)</span>
# <span class="ansi-green-intense-fg ansi-bold">     18</span>     df_1<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;matches&#39;</span><span class="ansi-blue-fg">]</span> <span class="ansi-blue-fg">=</span> m
# <span class="ansi-green-intense-fg ansi-bold">     19</span>
# <span class="ansi-green-fg">---&gt; 20</span><span class="ansi-red-fg">     </span>m2 <span class="ansi-blue-fg">=</span> df_1<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;matches&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">.</span>apply<span class="ansi-blue-fg">(</span><span class="ansi-green-fg">lambda</span> x<span class="ansi-blue-fg">:</span> <span class="ansi-blue-fg">&#39;, &#39;</span><span class="ansi-blue-fg">.</span>join<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">[</span>i<span class="ansi-blue-fg">[</span><span class="ansi-cyan-fg">0</span><span class="ansi-blue-fg">]</span> <span class="ansi-green-fg">for</span> i <span class="ansi-green-fg">in</span> x <span class="ansi-green-fg">if</span> i<span class="ansi-blue-fg">[</span><span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">]</span> <span class="ansi-blue-fg">&gt;=</span> threshold<span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     21</span>     df_1<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;matches&#39;</span><span class="ansi-blue-fg">]</span> <span class="ansi-blue-fg">=</span> m2
# <span class="ansi-green-intense-fg ansi-bold">     22</span>
#
# <span class="ansi-red-fg">TypeError</span>: sequence item 0: expected str instance, float found</div>

# %%
fpd.fuzzy_merge(F, FH,
                left_on=['description'],
                right_on=['description'],
                ignore_case=True,
                method='levenshtein',
                threshold=0.95,
                keep='all',
               join='full-outer')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">TypeError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-4464235365954451&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> fpd.fuzzy_merge(F.dropna(), FH.dropna(),
# </span><span class="ansi-green-intense-fg ansi-bold">      2</span>                 left_on<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;description&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span>                 right_on<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;description&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>                 ignore_case<span class="ansi-blue-fg">=</span><span class="ansi-green-fg">True</span><span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span>                 method<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;levenshtein&#39;</span><span class="ansi-blue-fg">,</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/fuzzy_pandas/fuzzy_merge.py</span> in <span class="ansi-cyan-fg">fuzzy_merge</span><span class="ansi-blue-fg">(df1, df2, on, left_on, right_on, keep, keep_left, keep_right, method, threshold, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    113</span>
# <span class="ansi-green-intense-fg ansi-bold">    114</span>     output <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">]</span>
# <span class="ansi-green-fg">--&gt; 115</span><span class="ansi-red-fg">     </span>output<span class="ansi-blue-fg">.</span>extend<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;1.&#39;</span> <span class="ansi-blue-fg">+</span> col <span class="ansi-green-fg">for</span> col <span class="ansi-green-fg">in</span> <span class="ansi-blue-fg">(</span>keep_left <span class="ansi-green-fg">or</span> left_on<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    116</span>     output<span class="ansi-blue-fg">.</span>extend<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;2.&#39;</span> <span class="ansi-blue-fg">+</span> col <span class="ansi-green-fg">for</span> col <span class="ansi-green-fg">in</span> <span class="ansi-blue-fg">(</span>keep_right <span class="ansi-green-fg">or</span> right_on<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    117</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/fuzzy_pandas/fuzzy_merge.py</span> in <span class="ansi-cyan-fg">&lt;listcomp&gt;</span><span class="ansi-blue-fg">(.0)</span>
# <span class="ansi-green-intense-fg ansi-bold">    113</span>
# <span class="ansi-green-intense-fg ansi-bold">    114</span>     output <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">]</span>
# <span class="ansi-green-fg">--&gt; 115</span><span class="ansi-red-fg">     </span>output<span class="ansi-blue-fg">.</span>extend<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;1.&#39;</span> <span class="ansi-blue-fg">+</span> col <span class="ansi-green-fg">for</span> col <span class="ansi-green-fg">in</span> <span class="ansi-blue-fg">(</span>keep_left <span class="ansi-green-fg">or</span> left_on<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    116</span>     output<span class="ansi-blue-fg">.</span>extend<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;2.&#39;</span> <span class="ansi-blue-fg">+</span> col <span class="ansi-green-fg">for</span> col <span class="ansi-green-fg">in</span> <span class="ansi-blue-fg">(</span>keep_right <span class="ansi-green-fg">or</span> right_on<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    117</span>
#
# <span class="ansi-red-fg">TypeError</span>: can only concatenate str (not &#34;int&#34;) to str</div>

# %%
#FR=pd.read_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P001-FR/04-DataAnalysis/pheno/FR_pheno_annotations.csv')
DI=pd.read_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P002-DI/04-DataAnalysis/pheno/DI_pheno_2015.description.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
FR.iloc[260:270]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[55]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>VARIABLE</th>
#       <th>LONGNAME</th>
#       <th>OPTIONS</th>
#       <th>NOTE</th>
#       <th>COHORTS</th>
#       <th>VARTYPE</th>
#       <th>CATEGORY</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>260</th>
#       <td>K_M2</td>
#       <td>2nd 2tributing cause of death, ICD</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Nominal</td>
#       <td>Disease</td>
#     </tr>
#     <tr>
#       <th>261</th>
#       <td>CHD</td>
#       <td>Coronary Heart Disease</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Disease</td>
#     </tr>
#     <tr>
#       <th>262</th>
#       <td>PREVAL_CHD</td>
#       <td>Prevalent Coronary heart disease</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>263</th>
#       <td>INCIDENT_CHD</td>
#       <td>Incident Coronary heart disease</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>264</th>
#       <td>CHD_AGE</td>
#       <td>Age at first Coronary heart disease event or a...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Numeric</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>265</th>
#       <td>CHD_AGEDIFF</td>
#       <td>CHD_AGE-baseline age</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Numeric</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>266</th>
#       <td>MI</td>
#       <td>Myocardial Infarction</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Disease</td>
#     </tr>
#     <tr>
#       <th>267</th>
#       <td>PREVAL_MI</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>268</th>
#       <td>INCIDENT_MI</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>269</th>
#       <td>MI_AGE</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Numeric</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
for idx,row in DI.iloc[range(278,852,5),].iterrows():
  condition=row['LONGNAME']
  if pd.isna(condition):
    print(idx)
    break
  DI.iloc[idx+1,1]="Prevalent "+condition
  DI.iloc[idx+2,1]="Incident "+condition
  DI.iloc[idx+3,1]="Age at first "+condition
  DI.iloc[idx+4,1]='Age at '+condition+"-baseline age"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
DI.iloc[270:290,]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[83]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>VARIABLE</th>
#       <th>LONGNAME</th>
#       <th>OPTIONS</th>
#       <th>VARTYPE</th>
#       <th>CATEGORY</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>270</th>
#       <td>PREVAL_HIBP</td>
#       <td>Prevalent Register based hypertension phenotype</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>271</th>
#       <td>INCIDENT_HIBP</td>
#       <td>Incident Register based hypertension phenotype</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>272</th>
#       <td>HIBP_AGE</td>
#       <td>Age at first Register based hypertension pheno...</td>
#       <td>NaN</td>
#       <td>Numeric</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>273</th>
#       <td>HIBP_AGEDIFF</td>
#       <td>Age at Register based hypertension phenotype-b...</td>
#       <td>NaN</td>
#       <td>Numeric</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>274</th>
#       <td>E.DIAB</td>
#       <td>E. means special governmental reimbursement fo...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>275</th>
#       <td>E.HIBP</td>
#       <td>Prevalent E. means special governmental reimbu...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>276</th>
#       <td>E.HFAIL</td>
#       <td>Incident E. means special governmental reimbur...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>277</th>
#       <td>E.AD</td>
#       <td>Age at first E. means special governmental rei...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>278</th>
#       <td>RX_A</td>
#       <td>Age at E. means special governmental reimburse...</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>279</th>
#       <td>PREVAL_RX_A</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>280</th>
#       <td>INCIDENT_RX_A</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>281</th>
#       <td>RX_A_AGE</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Numeric</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>282</th>
#       <td>RX_A_AGEDIFF</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Numeric</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>283</th>
#       <td>RX_A01</td>
#       <td>Stomatological preparations</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>284</th>
#       <td>PREVAL_RX_A01</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>285</th>
#       <td>INCIDENT_RX_A01</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>286</th>
#       <td>RX_A01_AGE</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Numeric</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>287</th>
#       <td>RX_A01_AGEDIFF</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Numeric</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>288</th>
#       <td>RX_A02</td>
#       <td>Drugs for acid related disorders</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>289</th>
#       <td>PREVAL_RX_A02</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
FR.to_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P001-FR/04-DataAnalysis/pheno/FR_pheno_annotations_partialfill.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
DI.to_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P002-DI/04-DataAnalysis/pheno/DI_pheno_2015.description_partialfill.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
DI[pd.isna(DI.LONGNAME)].tail(30)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[86]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>VARIABLE</th>
#       <th>LONGNAME</th>
#       <th>OPTIONS</th>
#       <th>VARTYPE</th>
#       <th>CATEGORY</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>844</th>
#       <td>PREVAL_RX_S</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>845</th>
#       <td>INCIDENT_RX_S</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>846</th>
#       <td>RX_S_AGE</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Numeric</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>847</th>
#       <td>RX_S_AGEDIFF</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Numeric</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>849</th>
#       <td>PREVAL_RX_V</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>850</th>
#       <td>INCIDENT_RX_V</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>851</th>
#       <td>RX_V_AGE</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Numeric</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>852</th>
#       <td>RX_V_AGEDIFF</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Numeric</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>876</th>
#       <td>BL_USE_RX_A10BD01</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>877</th>
#       <td>BL_USE_RX_A10BD02</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>878</th>
#       <td>BL_USE_RX_A10BD03</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>879</th>
#       <td>BL_USE_RX_A10BD04</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>880</th>
#       <td>BL_USE_RX_A10BD05</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>BL_USE_RX_A10BD06</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>882</th>
#       <td>BL_USE_RX_A10BD07</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>883</th>
#       <td>BL_USE_RX_A10BD08</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>884</th>
#       <td>BL_USE_RX_A10BD09</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>885</th>
#       <td>BL_USE_RX_A10BD10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>886</th>
#       <td>BL_USE_RX_A10BD11</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>887</th>
#       <td>BL_USE_RX_A10BD12</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>888</th>
#       <td>BL_USE_RX_A10BD13</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>889</th>
#       <td>BL_USE_RX_A10BD14</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>890</th>
#       <td>BL_USE_RX_A10BD15</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>891</th>
#       <td>BL_USE_RX_A10BD16</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>892</th>
#       <td>BL_USE_RX_A10BD17</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>893</th>
#       <td>BL_USE_RX_A10BD18</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>894</th>
#       <td>BL_USE_RX_A10BD19</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>895</th>
#       <td>BL_USE_RX_A10BD20</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>896</th>
#       <td>BL_USE_RX_A10BD21</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>897</th>
#       <td>BL_USE_RX_A10BD22</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.read_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P003-FH/04-DataAnalysis/pheno/FH_exam8_plasma_phenotype.description.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[145]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>idtype</td>
#       <td>idtype</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>id</td>
#       <td>id</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>SubjectID</td>
#       <td>idtype-id</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>framid</td>
#       <td>ID for genotyping data</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>dob</td>
#       <td>Date of Birth</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>785</th>
#       <td>early_dm</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>786</th>
#       <td>neverobese</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>787</th>
#       <td>fgl100</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>788</th>
#       <td>neverdm</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>789</th>
#       <td>hardcvdever</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <p>790 rows × 2 columns</p>
# </div>

# %%
FH[pd.isna(FH.description)].head(30)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>278</th>
#       <td>aspirin8</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>280</th>
#       <td>fibrate8</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>281</th>
#       <td>beta8</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>289</th>
#       <td>immuno8</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>291</th>
#       <td>metformin8</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>325</th>
#       <td>soeyear</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>331</th>
#       <td>cancer_date</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>368</th>
#       <td>sqrtavgwell</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>381</th>
#       <td>peak1_a2ch</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>382</th>
#       <td>peak2_a2ch</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>383</th>
#       <td>peak1_a4ch</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>384</th>
#       <td>peak2_a4ch</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>385</th>
#       <td>peak1_psax</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>386</th>
#       <td>peak2_psax</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>387</th>
#       <td>peakratio_a2ch</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>388</th>
#       <td>peakratio_a4ch</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>389</th>
#       <td>peakratio_psax</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>440</th>
#       <td>sic</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>441</th>
#       <td>idtypestr</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>442</th>
#       <td>idstr</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>686</th>
#       <td>fvc5</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>687</th>
#       <td>fvc6</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>688</th>
#       <td>fvc7</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>689</th>
#       <td>fvc8</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>690</th>
#       <td>COGSCR5</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>691</th>
#       <td>COGSCR6</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>692</th>
#       <td>COGSCR7</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>693</th>
#       <td>cogscr8</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>694</th>
#       <td>f_bls5</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>695</th>
#       <td>f_bls6</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
FR.LONGNAME.fillna('FR',inplace=True)
FR[pd.isna(FR.LONGNAME)]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[153]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>VARIABLE</th>
#       <th>LONGNAME</th>
#       <th>OPTIONS</th>
#       <th>NOTE</th>
#       <th>COHORTS</th>
#       <th>VARTYPE</th>
#       <th>CATEGORY</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>

# %%
H=pd.read_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P004-ME/04-DataAnalysis/pheno/ME_fuzzy_description.csv')
H.head(20)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>index</th>
#       <th>description</th>
#       <th>variable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#       <td>region of birth - maternal grandmother</td>
#       <td>mmrgbth1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>1</td>
#       <td>region of birth - paternal grandmother</td>
#       <td>pmrgbth1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>2</td>
#       <td>where do you go for medical care</td>
#       <td>medcare2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>3</td>
#       <td>#  adults age &gt; 65 supported by family income</td>
#       <td>nhhlde1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>4</td>
#       <td>#  of times treated w/ antibiotics, past year</td>
#       <td>abnum1, ab1ynum2, ab1ynum3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>5</td>
#       <td>#  teeth lost due to gum disease</td>
#       <td>tthnum1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>6</td>
#       <td># adults &gt; 65 supported by family income</td>
#       <td>nhhlde2, nhhlde5</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>7</td>
#       <td># children supported by family income</td>
#       <td>nhhldc1, nhhldc2, nhhldc5</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>8</td>
#       <td># drinks per week (current and former drinkers)</td>
#       <td>alcwk1c</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>9</td>
#       <td># drinks per week (current drinkers)</td>
#       <td>alcwkc1</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>10</td>
#       <td>10</td>
#       <td># drinks per week when drinking (former drinkers)</td>
#       <td>alcwkp1</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>11</td>
#       <td>11</td>
#       <td># of beers per week</td>
#       <td>beerwk2</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>12</td>
#       <td>12</td>
#       <td># of drinks of liquor/mixed drinks per week</td>
#       <td>liqwk2</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>13</td>
#       <td>13</td>
#       <td># of live births</td>
#       <td>birthn1</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>14</td>
#       <td>14</td>
#       <td># of menstrual periods in past 12 months</td>
#       <td>prdsnum1, prdsnum2, prdsnum3</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>15</td>
#       <td>15</td>
#       <td># of ovaries removed</td>
#       <td>ovaremn1, ovaremn2, ovaremn3</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>16</td>
#       <td>16</td>
#       <td># of pregnancies</td>
#       <td>pregn1</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>17</td>
#       <td>17</td>
#       <td># of times treated w/ antibiotics (past 5 year...</td>
#       <td>noab5y1</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>18</td>
#       <td>18</td>
#       <td># of times treated w/ antibiotics (past year) ...</td>
#       <td>noab1, noab2, noab3</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>19</td>
#       <td>19</td>
#       <td># of times treated w/ antibiotics, last five y...</td>
#       <td>ab5ynum1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
fpd.fuzzy_merge(H, FR,
                left_on=['description'],
                right_on=['LONGNAME'],
                ignore_case=True,
                method='levenshtein',
                threshold=0.6,
                keep='all',
               join='full-outer').head(40)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_g
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>description</th>
#       <th>variable</th>
#       <th>VARIABLE</th>
#       <th>LONGNAME</th>
#       <th>OPTIONS</th>
#       <th>NOTE</th>
#       <th>COHORTS</th>
#       <th>VARTYPE</th>
#       <th>CATEGORY</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>135</td>
#       <td>alpha-glucosidase inhibitors</td>
#       <td>agdi1c, agdi2c, agdi3c, agdi4c, agdi5c, agdi6c</td>
#       <td>RX_A10BF</td>
#       <td>Alpha glucosidase inhibitors</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>135</td>
#       <td>alpha-glucosidase inhibitors</td>
#       <td>agdi1c, agdi2c, agdi3c, agdi4c, agdi5c, agdi6c</td>
#       <td>BL_USE_RX_A10BF</td>
#       <td>Alpha glucosidase inhibitors</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>148</td>
#       <td>any gout medications</td>
#       <td>gout1c, gout2c, gout3c, gout4c, gout5c, gout6c</td>
#       <td>RX_B</td>
#       <td>Hematologic medications</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>148</td>
#       <td>any gout medications</td>
#       <td>gout1c, gout2c, gout3c, gout4c, gout5c, gout6c</td>
#       <td>RX_S</td>
#       <td>Sensory organ medications</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>148</td>
#       <td>any gout medications</td>
#       <td>gout1c, gout2c, gout3c, gout4c, gout5c, gout6c</td>
#       <td>BL_USE_RX_B</td>
#       <td>Hematologic medications</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>148</td>
#       <td>any gout medications</td>
#       <td>gout1c, gout2c, gout3c, gout4c, gout5c, gout6c</td>
#       <td>BL_USE_RX_S</td>
#       <td>Sensory organ medications</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>172</td>
#       <td>biguanides</td>
#       <td>bgnd1c, bgnd2c, bgnd3c, bgnd4c, bgnd5c, bgnd6c</td>
#       <td>RX_A10BA</td>
#       <td>Biguanides</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>172</td>
#       <td>biguanides</td>
#       <td>bgnd1c, bgnd2c, bgnd3c, bgnd4c, bgnd5c, bgnd6c</td>
#       <td>BL_USE_RX_A10BA</td>
#       <td>Biguanides</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>173</td>
#       <td>bile-acid sequestrants</td>
#       <td>basq1c, basq2c, basq3c, basq4c, basq5c, basq6c</td>
#       <td>RX_C10AC</td>
#       <td>Bile acid sequestrants</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>173</td>
#       <td>bile-acid sequestrants</td>
#       <td>basq1c, basq2c, basq3c, basq4c, basq5c, basq6c</td>
#       <td>BL_USE_RX_C10AC</td>
#       <td>Bile acid sequestrants</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>202</td>
#       <td>body mass index (kg/m^2)</td>
#       <td>bmi2c, bmi3c, bmi4c, bmi5c, bmi6c</td>
#       <td>BMI</td>
#       <td>Body mass index</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Numeric</td>
#       <td>Physical</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>208</td>
#       <td>c-reactive protein (crp) (mg/l)</td>
#       <td>crp1</td>
#       <td>CRP</td>
#       <td>C-reactive protein (mg/l)</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Numeric</td>
#       <td>Biomarker</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>209</td>
#       <td>c-reactive protein (mg/l)</td>
#       <td>crp4</td>
#       <td>CRP</td>
#       <td>C-reactive protein (mg/l)</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Numeric</td>
#       <td>Biomarker</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>210</td>
#       <td>c-reactive protein comments</td>
#       <td>crptx4</td>
#       <td>CRP</td>
#       <td>C-reactive protein (mg/l)</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Numeric</td>
#       <td>Biomarker</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>211</td>
#       <td>c-reactive protein missing value</td>
#       <td>crp4m</td>
#       <td>CRP</td>
#       <td>C-reactive protein (mg/l)</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Numeric</td>
#       <td>Biomarker</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>299</td>
#       <td>current smoking status</td>
#       <td>smkstat4, smkstat5</td>
#       <td>CURR_SMOKE</td>
#       <td>Current smoker 1=yes</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Lifestyle</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>320</td>
#       <td>diabetes meds, type</td>
#       <td>dbhxtyp1</td>
#       <td>DIAB</td>
#       <td>Diabetes type 1 or type 2</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Disease</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>322</td>
#       <td>diastolic blood pressure after series 7 mri</td>
#       <td>postdia1</td>
#       <td>SYS1</td>
#       <td>Systolic blood pressure 1st measurement</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR07</td>
#       <td>Numeric</td>
#       <td>Physical</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>322</td>
#       <td>diastolic blood pressure after series 7 mri</td>
#       <td>postdia1</td>
#       <td>DIAS1</td>
#       <td>Diastolic blood pressure 1st measurement</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR07</td>
#       <td>Numeric</td>
#       <td>Physical</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>322</td>
#       <td>diastolic blood pressure after series 7 mri</td>
#       <td>postdia1</td>
#       <td>DIAS2</td>
#       <td>Diastolic blood pressure 2nd measurement</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR07</td>
#       <td>Numeric</td>
#       <td>Physical</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>322</td>
#       <td>diastolic blood pressure after series 7 mri</td>
#       <td>postdia1</td>
#       <td>DIAS3</td>
#       <td>Diastolic blood pressure 3rd measurement</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR07</td>
#       <td>Numeric</td>
#       <td>Physical</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>323</td>
#       <td>diastolic blood pressure before series 7 mri</td>
#       <td>predia1</td>
#       <td>DIAS1</td>
#       <td>Diastolic blood pressure 1st measurement</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR07</td>
#       <td>Numeric</td>
#       <td>Physical</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>323</td>
#       <td>diastolic blood pressure before series 7 mri</td>
#       <td>predia1</td>
#       <td>DIAS2</td>
#       <td>Diastolic blood pressure 2nd measurement</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR07</td>
#       <td>Numeric</td>
#       <td>Physical</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>323</td>
#       <td>diastolic blood pressure bef
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>

# %%
ME=pd.read_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P002-DI/04-DataAnalysis/pheno/DI_pheno_2015.description.csv')
FH=pd.read_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P003-FH/04-DataAnalysis/pheno/FH_exam8_plasma_phenotype.description.csv')
DI=pd.read_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P002-DI/04-DataAnalysis/pheno/DI_pheno_2015.description_partialfill.csv')
FR=pd.read_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P001-FR/04-DataAnalysis/pheno/FR_pheno_annotations_partialfill.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
FR.loc[2,['VARIABLE','LONGNAME']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: VARIABLE                                             STOOL_ID
# LONGNAME    Id from fecal samples (FR02); ID of stool samp...
# Name: 2, dtype: object</div>

# %%
pd.read_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P005-AR/04-DataAnalysis/pheno/AR_pheno_v2samples.description.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>description</th>
#       <th>note</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AGE_V1</td>
#       <td>V1 Age in years (not rounded)</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AGE_V2</td>
#       <td>V2 Age in years (not rounded)</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AGE_V3</td>
#       <td>V3 Age in years (not rounded)</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>AGE_V4</td>
#       <td>V4 Age in years (not rounded)</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>AGE_V5</td>
#       <td>V5 Age in years (not rounded)</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>854</th>
#       <td>walkcomp</td>
#       <td>Frailty component: walking speed</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>855</th>
#       <td>walkspeed15ft61</td>
#       <td>V6 Time in seconds used to walk 15ft - frailty...</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>856</th>
#       <td>white</td>
#       <td>V1 Race=W</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>857</th>
#       <td>wsthpr61</td>
#       <td>V6 Waist-to-Hip Ratio</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>858</th>
#       <td>wtlosscomp10</td>
#       <td>Frailty component: weight loss</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <p>859 rows × 3 columns</p>
# </div>

# %%
pd.read_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P005-AR/04-DataAnalysis/pheno/AR_biolincc_2020b_v2_pheno.description.csv').iloc[50:80,]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>50</th>
#       <td>LOGSCR_V2</td>
#       <td>V2 Log Calibrated Serum Creatinine mg/dL</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>LOGSCR_V4</td>
#       <td>V4 Log Calibrated Serum Creatinine mg/dL</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>LOGSCR_V5</td>
#       <td>V5 Log Serum Creatinine mg/dL Reference</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>URIC_V1</td>
#       <td>V1 Calibrated Uric Acid mg/dL</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>URIC_V2</td>
#       <td>V2 Calibrated Uric Acid mg/dL</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>URIC_V4</td>
#       <td>V4 Calibrated Uric Acid mg/dL</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>URIC_V5</td>
#       <td>V5 Uric Acid mg/dL Reference (chm27)</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>TOTCHOL_V1</td>
#       <td>V1 Total Cholesterol mg/dL (lip01)</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>TOTCHOL_V2</td>
#       <td>V2 Total Cholesterol mg/dL (lipb01a)</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>TOTCHOL_V3</td>
#       <td>V3 Total Cholesterol mg/dL (lipc1a)</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>TOTCHOL_V4</td>
#       <td>V4 Total Cholesterol mg/dL (lipd1a)</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>TOTCHOL_V5</td>
#       <td>V5 Total Cholesterol mg/dL Reference (lip3)</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>GLUC_V1</td>
#       <td>V1 Total Glucose mg/dL (glucos01)</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>GLUC_V2</td>
#       <td>V2 Total Glucose mg/dL (chmb07)</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>GLUC_V3</td>
#       <td>V3 Total Glucose mg/dL (lipc4a)</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>GLUC_V4</td>
#       <td>V4 Total Glucose mg/dL (lipd4a)</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>GLUC_V5</td>
#       <td>V5 Total Glucose mg/dL Reference (lip23)</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>CRP_V4</td>
#       <td>V4 C-Reactive Protein mg/L (hscrp)</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>CRP_V5</td>
#       <td>V5 C-Reactive Protein mg/L Reference (lip33)</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>HDL_V1</td>
#       <td>V1 HDL mg/dL (hdl01 in derived data set)</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>HDL_V2</td>
#       <td>V2 HDL mg/dL (lipb03a)</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>HDL_V3</td>
#       <td>V3 HDL mg/dL (lipc3a)</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>HDL_V4</td>
#       <td>V4 HDL mg/dL (lipd3a)</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>HDL_V5</td>
#       <td>V5 HDL mg/dL Reference *ASSAY METHOD CHANGE* (...</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>TGS_V1</td>
#       <td>V1 Trigylcerides mg/dL (lipa02)</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>TGS_V2</td>
#       <td>V2 Trigylcerides mg/dL (lipb02)</td>
#     </tr>
#     <tr>
#       <th>76</th>
#       <td>TGS_V3</td>
#       <td>V3 Trigylcerides mg/dL (lipc2a)</td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td>TGS_V4</td>
#       <td>V4 Trigylcerides mg/dL (lipd2a)</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>TGS_V5</td>
#       <td>V5 Trigylcerides mg/dL Reference (lip8)</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>LDL_V1</td>
#       <td>V1 LDL mg/dL (ldl02 in derived data set)</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ARp=pd.read_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P005-AR/04-DataAnalysis/pheno/AR_pheno_v2samples.description.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ARp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>description</th>
#       <th>note</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AGE_V1</td>
#       <td>V1 Age in years (not rounded)</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AGE_V2</td>
#       <td>V2 Age in years (not rounded)</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AGE_V3</td>
#       <td>V3 Age in years (not rounded)</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>AGE_V4</td>
#       <td>V4 Age in years (not rounded)</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>AGE_V5</td>
#       <td>V5 Age in years (not rounded)</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>854</th>
#       <td>walkcomp</td>
#       <td>Frailty component: walking speed</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>855</th>
#       <td>walkspeed15ft61</td>
#       <td>V6 Time in seconds used to walk 15ft - frailty...</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>856</th>
#       <td>white</td>
#       <td>V1 Race=W</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>857</th>
#       <td>wsthpr61</td>
#       <td>V6 Waist-to-Hip Ratio</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>858</th>
#       <td>wtlosscomp10</td>
#       <td>Frailty component: weight loss</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <p>859 rows × 3 columns</p>
# </div>

# %%
simple=[]

ARp=ARp.drop_duplicates().reset_index(drop=True)
for idx,row in ARp.iterrows():
  if row['description']=='ARp':
    simple.append(row['variable'])
  elif re.search('V5 V5',row['description']):
    string=re.split('V5',row['description'])[2].strip()
    simple.append(string)
  elif re.search('^V[1-9]',row['description']):
    string=re.split('V[1-9]',row['description'])[1].strip()
    simple.append(string)

    
  elif re.search('V[1-9]$',row['description']):
    string=re.split('V[1-9]',row['description'])[0].strip()
    simple.append(string)
    
    
  else:
    simple.append(row['description'].strip())
    
ARp['simple_desc']=simple
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ARp[ARp.variable.str.contains('EGFRSCRCYSC_V5')]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[160]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>description</th>
#       <th>note</th>
#       <th>simple_desc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>86</th>
#       <td>EGFRSCRCYSC_V5</td>
#       <td>V5 V5 eGFR- Creatinine and Cystatin-C (mL/min/...</td>
#       <td>NaN</td>
#       <td>eGFR- Creatinine and Cystatin-C (mL/min/1.73 m...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ARp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[135]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>description</th>
#       <th>note</th>
#       <th>simple_desc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AGE_V1</td>
#       <td>V1 Age in years (not rounded)</td>
#       <td>NaN</td>
#       <td>Age in years (not rounded)</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AGE_V2</td>
#       <td>V2 Age in years (not rounded)</td>
#       <td>NaN</td>
#       <td>Age in years (not rounded)</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AGE_V3</td>
#       <td>V3 Age in years (not rounded)</td>
#       <td>NaN</td>
#       <td>Age in years (not rounded)</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>AGE_V4</td>
#       <td>V4 Age in years (not rounded)</td>
#       <td>NaN</td>
#       <td>Age in years (not rounded)</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>AGE_V5</td>
#       <td>V5 Age in years (not rounded)</td>
#       <td>NaN</td>
#       <td>Age in years (not rounded)</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>854</th>
#       <td>walkcomp</td>
#       <td>Frailty component: walking speed</td>
#       <td>NaN</td>
#       <td>Frailty component: walking speed</td>
#     </tr>
#     <tr>
#       <th>855</th>
#       <td>walkspeed15ft61</td>
#       <td>V6 Time in seconds used to walk 15ft - frailty...</td>
#       <td>NaN</td>
#       <td>Time in seconds used to walk 15ft - frailty sl...</td>
#     </tr>
#     <tr>
#       <th>856</th>
#       <td>white</td>
#       <td>V1 Race=W</td>
#       <td>NaN</td>
#       <td>Race=W</td>
#     </tr>
#     <tr>
#       <th>857</th>
#       <td>wsthpr61</td>
#       <td>V6 Waist-to-Hip Ratio</td>
#       <td>NaN</td>
#       <td>Waist-to-Hip Ratio</td>
#     </tr>
#     <tr>
#       <th>858</th>
#       <td>wtlosscomp10</td>
#       <td>Frailty component: weight loss</td>
#       <td>NaN</td>
#       <td>Frailty component: weight loss</td>
#     </tr>
#   </tbody>
# </table>
# <p>859 rows × 4 columns</p>
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ARp=ARp.dropna(subset=['variable'])
ARp.description.fillna('ARp',inplace=True)
ARp[pd.isna(ARp.description)]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[62]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>description</th>
#       <th>note</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>

# %%
ARp_grouped=ARp.groupby(['simple_desc'],as_index=False)['variable'].apply(', '.join).reset_index()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ARp_grouped.head(30)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[163]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>simple_desc</th>
#       <th>variable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>% of v4 weight change from v4 to v5 (neg val m...</td>
#       <td>v4v5wtdeltap51</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>(Assumed Complete) Follow up time for DEAD17 (...</td>
#       <td>FUTIMED_BWH</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>(Assumed Complete) Follow up time for DTHHF (d...</td>
#       <td>FUTIME_DTHHF_BWH</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>(Assumed Complete) Follow-up time for INCHF17 ...</td>
#       <td>C7_FUTIMEHF_BWH</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>4M walking speed for trial 1 (m/sec)</td>
#       <td>tr1walk4msp61</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>4M walking speed for trial 2 (m/sec)</td>
#       <td>tr2walk4msp61</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>AF at exam 1 (Prevalent AF) (1=yes, 0=no, miss...</td>
#       <td>afecgv1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>AF identified through ECG in exams 2, 3 or 4 b...</td>
#       <td>afecgby11</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>AF identified through death certificate by 201...</td>
#       <td>afdthby11</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>AF identified through hospital discharge code ...</td>
#       <td>afhosp1by11</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>10</td>
#       <td>ARIC patient acrostic ID</td>
#       <td>ech2, eco2</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>11</td>
#       <td>ARIC patient identifier</td>
#       <td>ech1, eco1</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>12</td>
#       <td>AV VTI (cm)</td>
#       <td>ech34</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>13</td>
#       <td>AV peak velocity (cm per sec)</td>
#       <td>ech32</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>14</td>
#       <td>Adjudicated inc HF, including MI+HF hosp (1=rE...</td>
#       <td>adjudhf_bwh_withmi</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>15</td>
#       <td>Adjudicated incident HF (1=rEF, 2=pEF, 3=uncla...</td>
#       <td>adjudhf_bwh</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>16</td>
#       <td>Age in years (not rounded)</td>
#       <td>AGE_V1, AGE_V2, AGE_V3, AGE_V4, AGE_V5</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>17</td>
#       <td>Aldosterone Antagonist in past 4 weeks - Using...</td>
#       <td>aldantmdcode61</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>18</td>
#       <td>Algorithmic Neurocognitive Classification</td>
#       <td>algdx61</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>19</td>
#       <td>Angiotensin II receptor antagonists in past 4 ...</td>
#       <td>angiantmdcode61</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>20</td>
#       <td>Angiotensin converting enzyme inhibitor in pas...</td>
#       <td>anginhmdcode61</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>21</td>
#       <td>Anti TPO (Visit 2), IU/mL</td>
#       <td>v2antitpo</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>22</td>
#       <td>Antianxiety Medication in past 4 weeks - Using...</td>
#       <td>antianxmdcode61</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>23</td>
#       <td>Anticoagulant Use in past 4 weeks - Using 2004...</td>
#       <td>anticoagcode61</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>24</td>
#       <td>Anticonvulsant Medication in past 4 weeks - Us...</td>
#       <td>anticonvmdcode61</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>25</td>
#       <td>Antidementia/Nootropic Medication in past 4 we...</td>
#       <td>antidemmdcode61</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>26</td>
#       <td>Antipsychotic Medication in past 4 weeks - Usi...</td>
#       <td>antipsychmdcode61</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>27</td>
#       <td>Any New/Recurrent HF event post-</td>
#       <td>postv5hf</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>28</td>
#       <td>Apical 4 chamber view: RV end diastolic area (...</td>
#       <td>ech36</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>29</td>
#       <td>Apical 4 chamber view: RV end systolic area (cm2)</td>
#       <td>ech37</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ARbio=pd.read_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P005-AR/04-DataAnalysis/pheno/AR_biolincc_2020b_v2_pheno.description.csv')
ARbio.iloc[50:100,]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[78]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>50</th>
#       <td>LOGSCR_V2</td>
#       <td>V2 Log Calibrated Serum Creatinine mg/dL</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>LOGSCR_V4</td>
#       <td>V4 Log Calibrated Serum Creatinine mg/dL</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>LOGSCR_V5</td>
#       <td>V5 Log Serum Creatinine mg/dL Reference</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>URIC_V1</td>
#       <td>V1 Calibrated Uric Acid mg/dL</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>URIC_V2</td>
#       <td>V2 Calibrated Uric Acid mg/dL</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>URIC_V4</td>
#       <td>V4 Calibrated Uric Acid mg/dL</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>URIC_V5</td>
#       <td>V5 Uric Acid mg/dL Reference (chm27)</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>TOTCHOL_V1</td>
#       <td>V1 Total Cholesterol mg/dL (lip01)</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>TOTCHOL_V2</td>
#       <td>V2 Total Cholesterol mg/dL (lipb01a)</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>TOTCHOL_V3</td>
#       <td>V3 Total Cholesterol mg/dL (lipc1a)</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>TOTCHOL_V4</td>
#       <td>V4 Total Cholesterol mg/dL (lipd1a)</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>TOTCHOL_V5</td>
#       <td>V5 Total Cholesterol mg/dL Reference (lip3)</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>GLUC_V1</td>
#       <td>V1 Total Glucose mg/dL (glucos01)</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>GLUC_V2</td>
#       <td>V2 Total Glucose mg/dL (chmb07)</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>GLUC_V3</td>
#       <td>V3 Total Glucose mg/dL (lipc4a)</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>GLUC_V4</td>
#       <td>V4 Total Glucose mg/dL (lipd4a)</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>GLUC_V5</td>
#       <td>V5 Total Glucose mg/dL Reference (lip23)</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>CRP_V4</td>
#       <td>V4 C-Reactive Protein mg/L (hscrp)</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>CRP_V5</td>
#       <td>V5 C-Reactive Protein mg/L Reference (lip33)</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>HDL_V1</td>
#       <td>V1 HDL mg/dL (hdl01 in derived data set)</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>HDL_V2</td>
#       <td>V2 HDL mg/dL (lipb03a)</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>HDL_V3</td>
#       <td>V3 HDL mg/dL (lipc3a)</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>HDL_V4</td>
#       <td>V4 HDL mg/dL (lipd3a)</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>HDL_V5</td>
#       <td>V5 HDL mg/dL Reference *ASSAY METHOD CHANGE* (...</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>TGS_V1</td>
#       <td>V1 Trigylcerides mg/dL (lipa02)</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>TGS_V2</td>
#       <td>V2 Trigylcerides mg/dL (lipb02)</td>
#     </tr>
#     <tr>
#       <th>76</th>
#       <td>TGS_V3</td>
#       <td>V3 Trigylcerides mg/dL (lipc2a)</td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td>TGS_V4</td>
#       <td>V4 Trigylcerides mg/dL (lipd2a)</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>TGS_V5</td>
#       <td>V5 Trigylcerides mg/dL Reference (lip8)</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>LDL_V1</td>
#       <td>V1 LDL mg/dL (ldl02 in derived data set)</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>LDL_V2</td>
#       <td>V2 LDL mg/dL (ldl22 in derived data set)</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>LDL_V3</td>
#       <td>V3 LDL mg/dL (ldl32 in derived data set)</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>LDL_V4</td>
#       <td>V4 LDL mg/dL (ldl41 in derived data set)</td>
#     </tr>
#     <tr>
#       <th>83</th>
#       <td>LDL_V5</td>
#       <td>V5 LDL mg/dL Reference (ldl51 in derived data ...</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>PRO_BNP_V4</td>
#       <td>V4 ProBNP pg/mL (pro_bnp)</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>PRO_BNP_V5</td>
#       <td>V5 ProBNP pg/mL Reference(lip43)</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>TROP_V4</td>
#       <td>V4 HS Troponin T mcg/L (hs_tnt)</td>
#     </tr>
#     <tr>
#       <th>87</th>
#       <td>TROP_V5</td>
#       <td>V5 HS Troponin T mcg/L Reference (lip38)</td>
#     </tr>
#     <tr>
#       <th>88</th>
#       <td>CYSC_V2</td>
#       <td>V2 Cystatin-C mg/L (V2CYS_GENT)</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td>CYSC_V4</td>
#       <td>V4 Calibrated Cystatin-C mg/L</td>
#     </tr>
#     <tr>
#       <th>90</th>
#       <td>CYSC_V5</td>
#       <td>V5 Cystatin-C mg/L Reference (cysc3)</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>EGFRSCR_V1</td>
#       <td>V1 eGFR-Creatinine (mL/min/1.73 m2)(calibrated...</td>
#     </tr>
#     <tr>
#       <th>92</th>
#       <td>EGFRSCR_V2</td>
#       <td>V2 eGFR-Creatinine (mL/min/1.73 m2)(calibrated...</td>
#     </tr>
#     <tr>
#       <th>93</th>
#       <td>EGFRSCR_V4</td>
#       <td>V4 eGFR-Creatinine (mL/min/1.73 m2)(calibrated...</td>
#     </tr>
#     <tr>
#       <th>94</th>
#       <td>EGFRSCR_V5</td>
#       <td>V5 eGFR-Creatinine (mL/min/1.73 m2)(reference ...</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>EGFRCYSC_V2</td>
#       <td>V2 eGFR-Cystatin-C (mL/min/1.73 m2)(uncalibrat...</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>EGFRCYSC_V4</td>
#       <td>V4 eGFR-Cystatin- C (mL/min/1.73 m2)(calibrate...</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>EGFRCYSC_V5</td>
#       <td>V5 eGFR-Cystatin-C (mL/min/1.73 m2)(reference ...</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>EGFRSCRCYSC_V2</td>
#       <td>V2 eGFR-Creatinine and Cystatin-C (mL/min/1.73...</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>EGFRSCRCYSC_V4</td>
#       <td>V4 eGFR-Creatinine and Cystatin-C (mL/min/1.73...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ARbio=pd.read_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P005-AR/04-DataAnalysis/pheno/AR_biolincc_2020b_v2_pheno.description.csv')

ARbio=ARbio.dropna(subset=['variable'])

ARbio.description.fillna('ARbio',inplace=True)
ARbio=ARbio.drop_duplicates().reset_index(drop=True)
simple=[]
for idx,row in ARbio.iterrows():
  if row['description']=='ARbio':
    simple.append(row['variable'])
  elif re.search('V5 V5',row['description']):
    string=re.split('V5',row['description'])[2].strip()
    simple.append(string)
  elif re.search('^V[1-9]',row['description']):
    string=re.split('V[1-9]',row['description'])[1].strip()
    simple.append(string)
    
  elif re.search('V[1-9]$',row['description']):
    string=re.split('V[1-9]',row['description'])[0].strip()
    simple.append(string)
  elif re.search('^Visit [1-9]',row['description']):
    string=re.split('Visit [1-9]',row['description'])[1].strip()
    simple.append(string)
  else:
    simple.append(row['description'].strip())
    
ARbio['simple_desc']=simple
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ARbio
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[150]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>description</th>
#       <th>simple_desc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ID_C</td>
#       <td>Scrambled Cohort Visit ID</td>
#       <td>Scrambled Cohort Visit ID</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Form</td>
#       <td>Form Code</td>
#       <td>Form Code</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>MCU0c</td>
#       <td>Person being interviewed</td>
#       <td>Person being interviewed</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>MCU1</td>
#       <td>Since last contacted, high blood pressure</td>
#       <td>Since last contacted, high blood pressure</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>MCU1b</td>
#       <td>CY of HBP</td>
#       <td>CY of HBP</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1187</th>
#       <td>V2T3DETECT</td>
#       <td>Indicator for T3 values outside LOD, 1=detecta...</td>
#       <td>Indicator for T3 values outside LOD, 1=detecta...</td>
#     </tr>
#     <tr>
#       <th>1188</th>
#       <td>V2NTPROBNPDETECT</td>
#       <td>Indicator for NT-ProBNP values outside LOD, 1=...</td>
#       <td>Indicator for NT-ProBNP values outside LOD, 1=...</td>
#     </tr>
#     <tr>
#       <th>1189</th>
#       <td>V2ANTITPODETECT</td>
#       <td>Indicator for Anti-TPO values outside LOD, 1=d...</td>
#       <td>Indicator for Anti-TPO values outside LOD, 1=d...</td>
#     </tr>
#     <tr>
#       <th>1190</th>
#       <td>V2BTHAW</td>
#       <td>Previously thawed visit 2 sample</td>
#       <td>Previously thawed visit 2 sample</td>
#     </tr>
#     <tr>
#       <th>1191</th>
#       <td>V2RBOX</td>
#       <td>Indicator for sample being in boxes R4, R8, or...</td>
#       <td>Indicator for sample being in boxes R4, R8, or...</td>
#     </tr>
#   </tbody>
# </table>
# <p>1192 rows × 3 columns</p>
# </div>

# %%
ARbio_grouped=ARbio.groupby(['simple_desc'],as_index=False)['variable'].apply(', '.join).reset_index(drop=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ARbio[ARbio.variable=='EGFRSCRCYSC_V5']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[155]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>description</th>
#       <th>simple_desc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>100</th>
#       <td>EGFRSCRCYSC_V5</td>
#       <td>V5 V5 eGFR- Creatinine and Cystatin-C (mL/min/...</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ARbio
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[158]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>description</th>
#       <th>simple_desc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ID_C</td>
#       <td>Scrambled Cohort Visit ID</td>
#       <td>Scrambled Cohort Visit ID</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Form</td>
#       <td>Form Code</td>
#       <td>Form Code</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>MCU0c</td>
#       <td>Person being interviewed</td>
#       <td>Person being interviewed</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>MCU1</td>
#       <td>Since last contacted, high blood pressure</td>
#       <td>Since last contacted, high blood pressure</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>MCU1b</td>
#       <td>CY of HBP</td>
#       <td>CY of HBP</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1187</th>
#       <td>V2T3DETECT</td>
#       <td>Indicator for T3 values outside LOD, 1=detecta...</td>
#       <td>Indicator for T3 values outside LOD, 1=detecta...</td>
#     </tr>
#     <tr>
#       <th>1188</th>
#       <td>V2NTPROBNPDETECT</td>
#       <td>Indicator for NT-ProBNP values outside LOD, 1=...</td>
#       <td>Indicator for NT-ProBNP values outside LOD, 1=...</td>
#     </tr>
#     <tr>
#       <th>1189</th>
#       <td>V2ANTITPODETECT</td>
#       <td>Indicator for Anti-TPO values outside LOD, 1=d...</td>
#       <td>Indicator for Anti-TPO values outside LOD, 1=d...</td>
#     </tr>
#     <tr>
#       <th>1190</th>
#       <td>V2BTHAW</td>
#       <td>Previously thawed visit 2 sample</td>
#       <td>Previously thawed visit 2 sample</td>
#     </tr>
#     <tr>
#       <th>1191</th>
#       <td>V2RBOX</td>
#       <td>Indicator for sample being in boxes R4, R8, or...</td>
#       <td>Indicator for sample being in boxes R4, R8, or...</td>
#     </tr>
#   </tbody>
# </table>
# <p>1192 rows × 3 columns</p>
# </div>

# %%
AR_full=ARp_grouped.append(ARbio_grouped)
AR_full
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[164]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>simple_desc</th>
#       <th>variable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>% of v4 weight change from v4 to v5 (neg val m...</td>
#       <td>v4v5wtdeltap51</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>(Assumed Complete) Follow up time for DEAD17 (...</td>
#       <td>FUTIMED_BWH</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2.0</td>
#       <td>(Assumed Complete) Follow up time for DTHHF (d...</td>
#       <td>FUTIME_DTHHF_BWH</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.0</td>
#       <td>(Assumed Complete) Follow-up time for INCHF17 ...</td>
#       <td>C7_FUTIMEHF_BWH</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.0</td>
#       <td>4M walking speed for trial 1 (m/sec)</td>
#       <td>tr1walk4msp61</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1134</th>
#       <td>NaN</td>
#       <td>vitamin B6 (mg)</td>
#       <td>VITB6</td>
#     </tr>
#     <tr>
#       <th>1135</th>
#       <td>NaN</td>
#       <td>vitamin C (mg)</td>
#       <td>VITC</td>
#     </tr>
#     <tr>
#       <th>1136</th>
#       <td>NaN</td>
#       <td>vitamin D (IU)</td>
#       <td>VITD</td>
#     </tr>
#     <tr>
#       <th>1137</th>
#       <td>NaN</td>
#       <td>waist-hip ratio</td>
#       <td>WSTHPR21</td>
#     </tr>
#     <tr>
#       <th>1138</th>
#       <td>NaN</td>
#       <td>zinc (mg)</td>
#       <td>ZINC</td>
#     </tr>
#   </tbody>
# </table>
# <p>1947 rows × 3 columns</p>
# </div>

# %%
AR_full[AR_full.duplicated(subset=['simple_desc'],keep=False)]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[182]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>simple_desc</th>
#       <th>variable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>153</th>
#       <td>History of Myocardial Infarction</td>
#       <td>hxofmi62</td>
#     </tr>
#     <tr>
#       <th>155</th>
#       <td>HsCRP (mg/L)</td>
#       <td>crp_v4</td>
#     </tr>
#     <tr>
#       <th>190</th>
#       <td>MD Diagnosed Myocardial Infarction</td>
#       <td>mddxmi62</td>
#     </tr>
#     <tr>
#       <th>478</th>
#       <td>History of Myocardial Infarction</td>
#       <td>hxofmi21</td>
#     </tr>
#     <tr>
#       <th>485</th>
#       <td>HsCRP (mg/L)</td>
#       <td>hscrp</td>
#     </tr>
#     <tr>
#       <th>592</th>
#       <td>MD Diagnosed Myocardial Infarction</td>
#       <td>mddxmi21</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
AR_full['variable']=[x.lower() for x in AR_full['variable']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
AR_full=AR_full[['simple_desc','variable']].drop_duplicates()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ARfull_grouped=AR_full.groupby(['simple_desc'],as_index=False)['variable'].apply(', '.join).reset_index(drop=True)
ARfull_grouped.to_csv('/dbfs/mnt/sapbio-client-001sap/001SAP21P005-AR/04-DataAnalysis/pheno/AR_full_grouped_partialfill.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
DI[pd.isna(DI['LONGNAME'])]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[189]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>VARIABLE</th>
#       <th>LONGNAME</th>
#       <th>OPTIONS</th>
#       <th>VARTYPE</th>
#       <th>CATEGORY</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>13</th>
#       <td>13</td>
#       <td>WESID</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>ID</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>14</td>
#       <td>WGSID</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>ID</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>15</td>
#       <td>BATCH</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Nominal</td>
#       <td>Technical</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>16</td>
#       <td>DNAPERM</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>876</th>
#       <td>876</td>
#       <td>BL_USE_RX_A10BD01</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>877</th>
#       <td>877</td>
#       <td>BL_USE_RX_A10BD02</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>878</th>
#       <td>878</td>
#       <td>BL_USE_RX_A10BD03</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>879</th>
#       <td>879</td>
#       <td>BL_USE_RX_A10BD04</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>880</th>
#       <td>880</td>
#       <td>BL_USE_RX_A10BD05</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>881</td>
#       <td>BL_USE_RX_A10BD06</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>882</th>
#       <td>882</td>
#       <td>BL_USE_RX_A10BD07</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>883</th>
#       <td>883</td>
#       <td>BL_USE_RX_A10BD08</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>884</th>
#       <td>884</td>
#       <td>BL_USE_RX_A10BD09</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>885</th>
#       <td>885</td>
#       <td>BL_USE_RX_A10BD10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>886</th>
#       <td>886</td>
#       <td>BL_USE_RX_A10BD11</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>887</th>
#       <td>887</td>
#       <td>BL_USE_RX_A10BD12</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>888</th>
#       <td>888</td>
#       <td>BL_USE_RX_A10BD13</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>889</th>
#       <td>889</td>
#       <td>BL_USE_RX_A10BD14</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>890</th>
#       <td>890</td>
#       <td>BL_USE_RX_A10BD15</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>891</th>
#       <td>891</td>
#       <td>BL_USE_RX_A10BD16</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>892</th>
#       <td>892</td>
#       <td>BL_USE_RX_A10BD17</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>893</th>
#       <td>893</td>
#       <td>BL_USE_RX_A10BD18</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>894</th>
#       <td>894</td>
#       <td>BL_USE_RX_A10BD19</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>895</th>
#       <td>895</td>
#       <td>BL_USE_RX_A10BD20</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>896</th>
#       <td>896</td>
#       <td>BL_USE_RX_A10BD21</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>897</th>
#       <td>897</td>
#       <td>BL_USE_RX_A10BD22</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
FRDI=FR.merge(DI,on='VARIABLE')[['VARIABLE','LONGNAME_x']].reset_index(drop=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
FRDI.columns=['variable','description']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ARfull_grouped
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[203]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>simple_desc</th>
#       <th>variable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td># CIGARETTES SMOKED A DAY NOW       Q48</td>
#       <td>hhxb48</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td># CIGARS OR CIGARILLOS PER WEEK     Q54</td>
#       <td>hhxb54</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td># DAYS PER 4 WEEKS TOOK HORMONE 1   Q29A</td>
#       <td>hhxb29a</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td># DAYS PER 4 WEEKS TOOK HORMONE 2   Q36A</td>
#       <td>hhxb36a</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td># DOSES HORMONE 1 PER DAY           Q29B</td>
#       <td>hhxb29b</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1883</th>
#       <td>vitamin B6 (mg)</td>
#       <td>vitb6</td>
#     </tr>
#     <tr>
#       <th>1884</th>
#       <td>vitamin C (mg)</td>
#       <td>vitc</td>
#     </tr>
#     <tr>
#       <th>1885</th>
#       <td>vitamin D (IU)</td>
#       <td>vitd</td>
#     </tr>
#     <tr>
#       <th>1886</th>
#       <td>waist-hip ratio</td>
#       <td>wsthpr21</td>
#     </tr>
#     <tr>
#       <th>1887</th>
#       <td>zinc (mg)</td>
#       <td>zinc</td>
#     </tr>
#   </tbody>
# </table>
# <p>1888 rows × 2 columns</p>
# </div>

# %%
FRDIAR=fpd.fuzzy_merge(FRDI.dropna(), ARfull_grouped.dropna(),
                left_on=['description'],
                right_on=['simple_desc'],
                ignore_case=True,
                method='levenshtein',
                threshold=0.6,
                keep='all',
               join='full-outer')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
FRDIAR.columns=['FRDI_variable','FRDI_description','AR_variable','AR_description']
#FRDIAR2=FRDIA
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
FRDIAR.to_csv('/dbfs/FileStore/users/adam.large@sapient.bio/FRDIAR.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %r



#library(SparkR)

meta <- read.df("/FileStore/users/adam.large@sapient.bio/FRDIAR.csv", header="true", inferSchema = "true", source="csv")
display(meta)

dim(meta)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>FRDI_variable</th><th>FRDI_description</th><th>AR_variable</th><th>AR_description</th></tr></thead><tbody><tr><td>0</td><td>SYS3</td><td>Systolic blood pressure 3rd measurement</td><td>Mean Systolic BP of 2nd and 3rd Measurements</td><td>systolic61</td></tr><tr><td>1</td><td>DIAS3</td><td>Diastolic blood pressure 3rd measurement</td><td>Mean Diastolic BP of 2nd and 3rd Measurements</td><td>diastolic61</td></tr><tr><td>2</td><td>BMI</td><td>Body mass index</td><td>Body Mass Index in Kg/m2</td><td>bmi61</td></tr><tr><td>3</td><td>BMI</td><td>Body mass index</td><td>body mass index in kg/m2</td><td>bmi21</td></tr><tr><td>4</td><td>WHR</td><td>waist hip ratio</td><td>Waist-to-Hip Ratio</td><td>wsthpr61</td></tr><tr><td>5</td><td>WHR</td><td>waist hip ratio</td><td>waist-hip ratio</td><td>wsthpr21</td></tr><tr><td>6</td><td>CURR_SMOKE</td><td>Current smoker 1=yes</td><td>Current Smoker Flag</td><td>cursmk21</td></tr><tr><td>7</td><td>EX_SMOKE</td><td>Former smoker 1=yes</td><td>Former Smoker Flag</td><td>forsmk21</td></tr><tr><td>8</td><td>KOL</td><td>Total cholesterol (mmol/l)</td><td>HDL (2) cholesterol in mmol/L</td><td>hd2siu21</td></tr><tr><td>9</td><td>KOL</td><td>Total cholesterol (mmol/l)</td><td>HDL (3) cholesterol in mmol/L</td><td>hd3siu21</td></tr><tr><td>10</td><td>KOL</td><td>Total cholesterol (mmol/l)</td><td>HDL cholesterol in mmol/L</td><td>hdlsiu21</td></tr><tr><td>11</td><td>KOL</td><td>Total cholesterol (mmol/l)</td><td>LDL cholesterol in mmol/L</td><td>ldlsiu22</td></tr><tr><td>12</td><td>KOL</td><td>Total cholesterol (mmol/l)</td><td>Total Cholesterol in SI Units</td><td>tchsiu61</td></tr><tr><td>13</td><td>KOL</td><td>Total cholesterol (mmol/l)</td><td>Total Cholesterol mg/dL (lip01)</td><td>totchol_v1</td></tr><tr><td>14</td><td>KOL</td><td>Total cholesterol (mmol/l)</td><td>Total Cholesterol mg/dL (lipb01a)</td><td>totchol_v2</td></tr><tr><td>15</td><td>KOL</td><td>Total cholesterol (mmol/l)</td><td>Total Cholesterol mg/dL (lipc1a)</td><td>totchol_v3</td></tr><tr><td>16</td><td>KOL</td><td>Total cholesterol (mmol/l)</td><td>Total Cholesterol mg/dL (lipd1a)</td><td>totchol_v4</td></tr><tr><td>17</td><td>KOL</td><td>Total cholesterol (mmol/l)</td><td>Visit 1 total cholesterol (mg/dL)</td><td>v1_lipa01</td></tr><tr><td>18</td><td>KOL</td><td>Total cholesterol (mmol/l)</td><td>Visit 2 total cholesterol (mg/dL)</td><td>v2_lipb01a</td></tr><tr><td>19</td><td>KOL</td><td>Total cholesterol (mmol/l)</td><td>Visit 3 total cholesterol (mg/dL)</td><td>v3_lipc1a</td></tr><tr><td>20</td><td>KOL</td><td>Total cholesterol (mmol/l)</td><td>Visit 4 total cholesterol (mg/dL)</td><td>v4_lipd1a</td></tr><tr><td>21</td><td>KOL</td><td>Total cholesterol (mmol/l)</td><td>Visit 5 Total cholesterol (mg/dL)</td><td>v5_chol</td></tr><tr><td>22</td><td>KOL</td><td>Total cholesterol (mmol/l)</td><td>dietary cholesterol (mg)</td><td>chol</td></tr><tr><td>23</td><td>KOL</td><td>Total cholesterol (mmol/l)</td><td>total cholesterol in mmol/L</td><td>tchsiu21</td></tr><tr><td>24</td><td>HDL</td><td>HDL cholesterol U(mmol/l)</td><td>HDL (2) cholesterol in mg/dL</td><td>hdl221</td></tr><tr><td>25</td><td>HDL</td><td>HDL cholesterol U(mmol/l)</td><td>HDL (2) cholesterol in mmol/L</td><td>hd2siu21</td></tr><tr><td>26</td><td>HDL</td><td>HDL cholesterol U(mmol/l)</td><td>HDL (3) cholesterol in mmol/L</td><td>hd3siu21</td></tr><tr><td>27</td><td>HDL</td><td>HDL cholesterol U(mmol/l)</td><td>HDL cholesterol in mmol/L</td><td>hdlsiu21</td></tr><tr><td>28</td><td>HDL</td><td>HDL cholesterol U(mmol/l)</td><td>LDL cholesterol in mmol/L</td><td>ldlsiu22</td></tr><tr><td>29</td><td>HDL</td><td>HDL cholesterol U(mmol/l)</td><td>total cholesterol in mmol/L</td><td>tchsiu21</td></tr><tr><td>30</td><td>TRIG</td><td>Triglycerides (mmol/l)</td><td>Total triglycerides in mmol/L</td><td>trgsiu21</td></tr><tr><td>31</td><td>TRIG</td>< ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>[1] 2869    5
#
# </pre>

# %%
fpd.fuzzy_merge(FRDI.dropna(), FH.dropna(),
                left_on=['description'],
                right_on=['description'],
                ignore_case=True,
                ignore_nonalpha=True,
                ignore_order_words=True,
                method='levenshtein',
                threshold=0.5,
                keep='all',
               join='full-outer').head(50)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[225]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>description</th>
#       <th>variable</th>
#       <th>description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>DIAS3</td>
#       <td>Diastolic blood pressure 3rd measurement</td>
#       <td>DBP3</td>
#       <td>Average diastolic blood pressure (mmHg), Exam 3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>BMI</td>
#       <td>Body mass index</td>
#       <td>BMI1</td>
#       <td>Body mass index (kg/m²), Exam 1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>BMI</td>
#       <td>Body mass index</td>
#       <td>BMI2</td>
#       <td>Body mass index (kg/m²), Exam 2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>BMI</td>
#       <td>Body mass index</td>
#       <td>BMI3</td>
#       <td>Body mass index (kg/m²), Exam 3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>BMI</td>
#       <td>Body mass index</td>
#       <td>BMI4</td>
#       <td>Body mass index (kg/m²), Exam 4</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>BMI</td>
#       <td>Body mass index</td>
#       <td>BMI5</td>
#       <td>Body mass index (kg/m²), Exam 5</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>BMI</td>
#       <td>Body mass index</td>
#       <td>BMI6</td>
#       <td>Body mass index (kg/m²), Exam 6</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>BMI</td>
#       <td>Body mass index</td>
#       <td>BMI7</td>
#       <td>Body mass index (kg/m²), Exam 7</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>BMI</td>
#       <td>Body mass index</td>
#       <td>BMI8</td>
#       <td>Body mass index (kg/m²), Exam 8</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>BMI</td>
#       <td>Body mass index</td>
#       <td>BMI9</td>
#       <td>Body mass index (kg/m²), Exam 9</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>BMI</td>
#       <td>Body mass index</td>
#       <td>lvmi</td>
#       <td>LV mass index</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>BP_TREAT</td>
#       <td>BP medication at baseline</td>
#       <td>intdate</td>
#       <td>Interpretation date</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>HRT</td>
#       <td>Hormone replacement therapy</td>
#       <td>hrt8</td>
#       <td>Hormone replacement therapy at Exam 8</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>PAASTO</td>
#       <td>Fasting, hours</td>
#       <td>fasting</td>
#       <td>FASTING FOR 8 HOURS</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>HDL1</td>
#       <td>HDL cholesterol (mg/dL), Exam 1</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>HDL2</td>
#       <td>HDL cholesterol (mg/dL), Exam 2</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>HDL3</td>
#       <td>HDL cholesterol (mg/dL), Exam 3</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>HDL4</td>
#       <td>HDL cholesterol (mg/dL), Exam 4</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>HDL5</td>
#       <td>HDL cholesterol (mg/dL), Exam 5</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>HDL6</td>
#       <td>HDL cholesterol (mg/dL), Exam 6</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>HDL7</td>
#       <td>HDL cholesterol (mg/dL), Exam 7</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>HDL8</td>
#       <td>HDL cholesterol (mg/dL), Exam 8</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>HDL9</td>
#       <td>HDL cholesterol (mg/dL), Exam 9</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>TC1</td>
#       <td>Total cholesterol (mg/dL), Exam 1</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>TC2</td>
#       <td>Total cholesterol (mg/dL), Exam 2</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>TC3</td>
#       <td>Total cholesterol (mg/dL), Exam 3</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>TC4</td>
#       <td>Total cholesterol (mg/dL), Exam 4</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>TC5</td>
#       <td>Total cholesterol (mg/dL), Exam 5</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>TC6</td>
#       <td>Total cholesterol (mg/dL), Exam 6</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>TC7</td>
#       <td>Total cholesterol (mg/dL), Exam 7</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>TC8</td>
#       <td>Total cholesterol (mg/dL), Exam 8</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>KOL</td>
#       <td>Total cholesterol (mmol/l)</td>
#       <td>TC9</td>
#       <td>Total cholesterol (mg/dL), Exam 9</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>HDL</td>
#       <td>HDL cholesterol U(mmol/l)</td>
#       <td>TC1</td>
#       <td>Total cholesterol (mg/dL), Exam 1</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>HDL</td>
#       <td>HDL cholesterol U(mmol/l)</td>
#       <td>TC2</td>
#       <td>Total cholesterol (mg/dL), Exam 2</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>HDL</td>
#       <td>HDL cholesterol U(mmol/l)</td>
#       <td>TC3</td>
#       <td>Total cholesterol (mg/dL), Exam 3</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>HDL</td>
#       <td>HDL cholesterol U(mmol/l)</td>
#       <td>TC4</td>
#       <td>Total cholesterol (mg/dL), Exam 4</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>HDL</td>
#       <td>HDL cholesterol U(mmol/l)</td>
#       <td>TC5</td>
#       <td>Total cholesterol (mg/dL), Exam 5</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>HDL</td>
#       <td>HDL cholesterol U(mmol/l)</td>
#       <td>TC6</td>
#       <td>Total cholesterol (mg/dL), Exam 6</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>HDL</td>
#       <td>HDL cholesterol U(mmol/l)</td>
#       <td>TC7</td>
#       <td>Total cholesterol (mg/dL), Exam 7</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>HDL</td>
#       <td>HDL cholesterol U(mmol/l)</td>
#       <td>TC8</td>
#       <td>Total cholesterol (mg/dL), Exam 8</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>HDL</td>
#       <td>HDL cholesterol U(mmol/l)</td>
#       <td>TC9</td>
#       <td>Total cholesterol (mg/dL), Exam 9</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>TRIG</td>
#       <td>Triglycerides (mmol/l)</td>
#       <td>TRIG1</td>
#       <td>Triglycerides (mg/dL), Exam 1</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>TRIG</td>
#       <td>Triglycerides (mmol/l)</td>
#       <td>TRIG2</td>
#       <td>Triglycerides (mg/dL), Exam 2</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>TRIG</td>
#       <td>Triglycerides (mmol/l)</td>
#       <td>TRIG3</td>
#       <td>Triglycerides (mg/dL), Exam 3</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>TRIG</td>
#       <td>Triglycerides (mmol/l)</td>
#       <td>TRIG4</td>
#       <td>Triglycerides (mg/dL), Exam 4</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>TRIG</td>
#       <td>Triglycerides (mmol/l)</td>
#       <td>TRIG5</td>
#       <td>Triglycerides (mg/dL), Exam 5</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>TRIG</td>
#       <td>Triglycerides (mmol

# %%
pd.set_option("display.max_rows", 999)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ARfull_grouped.iloc[1:100,]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[230]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>simple_desc</th>
#       <th>variable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td># CIGARS OR CIGARILLOS PER WEEK     Q54</td>
#       <td>hhxb54</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td># DAYS PER 4 WEEKS TOOK HORMONE 1   Q29A</td>
#       <td>hhxb29a</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td># DAYS PER 4 WEEKS TOOK HORMONE 2   Q36A</td>
#       <td>hhxb36a</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td># DOSES HORMONE 1 PER DAY           Q29B</td>
#       <td>hhxb29b</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td># DOSES HORMONE 2 PER DAY           Q36B</td>
#       <td>hhxb36b</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td># OF CANS OF BEER A WEEK            Q65</td>
#       <td>hhxb65</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td># OF DRINKS A WEEK BEFORE STOPPING  Q63</td>
#       <td>hhxb63</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td># OF DRINKS IN THE PAST 24 HOURS    Q67</td>
#       <td>hhxb67</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td># OF GLASSES OF WINE A WEEK         Q64</td>
#       <td>hhxb64</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td># OF HARD LIQUOR DRINKS A WEEK      Q66</td>
#       <td>hhxb66</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td># OF UNTRANSCRIBABLE MEDICATIONS  Q22</td>
#       <td>msrb22</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td># YRS STOPPED DRINKING?             Q60</td>
#       <td>hhxb60</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td># YRS YOU DID DRINK?                Q61</td>
#       <td>hhxb61</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>% Risk of Inc CHD w/in 10 yrs (V2)</td>
#       <td>chdrisk10yr_21</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>% of v4 weight change from v4 to v5 (neg val m...</td>
#       <td>v4v5wtdeltap51</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>%Risk of Inc Diabts w/in 9yrs (V2)</td>
#       <td>diabetesrisk9yr_21</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>%Risk of Inc Stroke w/in 10yrs (V2)</td>
#       <td>strokerisk10yr_21</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>(Assumed Complete) Follow up time for DEAD17 (...</td>
#       <td>futimed_bwh</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>(Assumed Complete) Follow up time for DTHHF (d...</td>
#       <td>futime_dthhf_bwh</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>(Assumed Complete) Follow-up time for INCHF17 ...</td>
#       <td>c7_futimehf_bwh</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>1 breath-hold leak &gt; 5%            Q08C</td>
#       <td>pftb08c</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>1 breath-hold leak &gt; 5%            Q10C</td>
#       <td>pftb10c</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>1 computr started aft expirat startQ10B</td>
#       <td>pftb10b</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>1 computr started after expir startQ08B</td>
#       <td>pftb08b</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>1 cough,inhalation present         Q08E</td>
#       <td>pftb08e</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>1 cough,inhalation present         Q10E</td>
#       <td>pftb10e</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>1 lo H2O  0 accept  9 no flo-vol lpQ08G</td>
#       <td>pftb08g</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>1 lo H2O  0 accept  9 no flo-vol lpQ10G</td>
#       <td>pftb10g</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>1 no plateau                       Q08F</td>
#       <td>pftb08f</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>1 no plateau                       Q10F</td>
#       <td>pftb10f</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>1 spirometer not calibrated correctQ08A</td>
#       <td>pftb08a</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>1 spirometer not calibrated correctQ10A</td>
#       <td>pftb10a</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>1 submaximal effort                Q08D</td>
#       <td>pftb08d</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>1 submaximal effort                Q10D</td>
#       <td>pftb10d</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>1,5-Anhydroglucitol (Visit 2), ug/mL</td>
#       <td>v2ag</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>1ST BP MEASUREMENT ZERO READING   Q14</td>
#       <td>sbpb14</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>1ST DIASTOLIC BP MEASUREMENT      Q13</td>
#       <td>sbpb13</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>1ST SYSTOLIC BP MEASUREMENT       Q12</td>
#       <td>sbpb12</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>2 OR MORE WHEEZING ATTACKS?       Q11</td>
#       <td>rpab11</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>2004 DRUG CODE Q04B</td>
#       <td>code1</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>2004 DRUG CODE Q05B</td>
#       <td>code2</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>2004 DRUG CODE Q06B</td>
#       <td>code3</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>2004 DRUG CODE Q07B</td>
#       <td>code4</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>2004 DRUG CODE Q08B</td>
#       <td>code5</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>2004 DRUG CODE Q09B</td>
#       <td>code6</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>2004 DRUG CODE Q10B</td>
#       <td>code7</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>2004 DRUG CODE Q11B</td>
#       <td>code8</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>2004 DRUG CODE Q12B</td>
#       <td>code9</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>2004 DRUG CODE Q13B</td>
#       <td>code10</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>2004 DRUG CODE Q14B</td>
#       <td>code11</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>2004 DRUG CODE Q15B</td>
#       <td>code12</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>2004 DRUG CODE Q16B</td>
#       <td>code13</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>2004 DRUG CODE Q17B</td>
#       <td>code14</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>2004 DRUG CODE Q18B</td>
#       <td>code15</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>2004 DRUG CODE Q19B</td>
#       <td>code16</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>2004 DRUG CODE Q20B</td>
#       <td>code17</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>25(OH) D3 epimer, ng/mL (quantifiable: &gt;=1.41 ...</td>
#       <td>d3epi</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>25(OH)D2, ng/mL</td>
#       <td>d2</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>25(OH)D3, ng/mL</td>
#       <td>d3</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>2ND AND 3RD DIASTOLIC BP AVERAGE  Q22</td>
#       <td>sbpb22</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>2ND AND 3RD SYSTOLIC BP AVERAGE   Q21</td>
#       <td>sbpb21</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>2ND BP MEASUREMENT ZERO READING   Q17</td>
#       <td>sbpb17</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>2ND DIASTOLIC BP MEASUREMENT      Q16</td>
#       <td>sbpb16</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>2ND SYSTOLIC BP MEASUREMENT       Q15</td>
#       <td>sbpb15</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>3 CONSECUTIVE MONS, MOST DAYS?    Q3</td>
#       <td>rpab03</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>3RD BP MEASUREMENT ZERO READING   Q20</td>
#       <td>sbpb20</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>3RD DIASTOLIC BP MEASUREMENT      Q19</td>
#       <td>sbpb19</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>3RD SYSTOLIC BP MEASUREMENT       Q18</td>
#       <td>sbpb18</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>4M walking speed for trial 1 (m/sec)</td>
#       <td>tr1walk4msp61</td>
#     </tr>
#     <tr>
#       <th>70</th>

# %%
FR[pd.isna(FR.LONGNAME)]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>VARIABLE</th>
#       <th>LONGNAME</th>
#       <th>OPTIONS</th>
#       <th>NOTE</th>
#       <th>COHORTS</th>
#       <th>VARTYPE</th>
#       <th>CATEGORY</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>12</th>
#       <td>12</td>
#       <td>WESID</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>NaN</td>
#       <td>ID</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>13</td>
#       <td>WGSID</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>NaN</td>
#       <td>ID</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>14</td>
#       <td>BATCH</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Nominal</td>
#       <td>Technical</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>15</td>
#       <td>DNAPERM</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1063</th>
#       <td>1063</td>
#       <td>BL_USE_RX_A10BD01</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1064</th>
#       <td>1064</td>
#       <td>BL_USE_RX_A10BD02</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1065</th>
#       <td>1065</td>
#       <td>BL_USE_RX_A10BD03</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1066</th>
#       <td>1066</td>
#       <td>BL_USE_RX_A10BD04</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1067</th>
#       <td>1067</td>
#       <td>BL_USE_RX_A10BD05</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1068</th>
#       <td>1068</td>
#       <td>BL_USE_RX_A10BD06</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1069</th>
#       <td>1069</td>
#       <td>BL_USE_RX_A10BD07</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1070</th>
#       <td>1070</td>
#       <td>BL_USE_RX_A10BD08</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1071</th>
#       <td>1071</td>
#       <td>BL_USE_RX_A10BD09</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1072</th>
#       <td>1072</td>
#       <td>BL_USE_RX_A10BD10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1073</th>
#       <td>1073</td>
#       <td>BL_USE_RX_A10BD11</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1074</th>
#       <td>1074</td>
#       <td>BL_USE_RX_A10BD12</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1075</th>
#       <td>1075</td>
#       <td>BL_USE_RX_A10BD13</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1076</th>
#       <td>1076</td>
#       <td>BL_USE_RX_A10BD14</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1077</th>
#       <td>1077</td>
#       <td>BL_USE_RX_A10BD15</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1078</th>
#       <td>1078</td>
#       <td>BL_USE_RX_A10BD16</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1079</th>
#       <td>1079</td>
#       <td>BL_USE_RX_A10BD17</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1080</th>
#       <td>1080</td>
#       <td>BL_USE_RX_A10BD18</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1081</th>
#       <td>1081</td>
#       <td>BL_USE_RX_A10BD19</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1082</th>
#       <td>1082</td>
#       <td>BL_USE_RX_A10BD20</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1083</th>
#       <td>1083</td>
#       <td>BL_USE_RX_A10BD21</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#     <tr>
#       <th>1084</th>
#       <td>1084</td>
#       <td>BL_USE_RX_A10BD22</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>FR02,FR07</td>
#       <td>Dichotomous</td>
#       <td>Medication</td>
#     </tr>
#   </tbody>
# </table>
# </div>
